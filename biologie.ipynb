# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = [21, .04, 78, 1] 
keys = ['Sauerstoff', 'Kohlenstoffdioxid', 'Stickstoff', 'Edelgase'] 
  
palette_color = sn.color_palette('bright') 
  
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%') 
  
plt.show()

# %%
data1 = [17, 4, 78, 1] 
keys2 = ['Sauerstoff', 'Kohlenstoffdioxid', 'Stickstoff', 'Edelgase'] 
  
palette_color = sn.color_palette('bright') 
  
plt.pie(data1, labels=keys2, colors=palette_color, autopct='%.0f%%') 
  
plt.show()
