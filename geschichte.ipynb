# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("geschichte.csv")
df
# Out:
#          Name             Wichtigste Erungschaften  Geburtsdatum  Sterbdatum
# 0  Pythagoras  Theorem von Pythagoras(a^2+b^2=c^2)    572 v.Chr.  490 v.Chr.
# 1  Archimedes                                   pi    287 v.Chr.  212 v.Chr.
# 2      Thales                      Satz des Thales    624 v.Chr.  548 v.Chr.
# 3      Euklid                Euklidische Geometrie    365 v.Chr.  300 v.Chr.
# 4    Hipparch          Grundlage von Trigonometrie    190 v.Chr.  120 v.Chr.

# %%
x = np.arange(0, 5*np.pi, 0.1)
y = np.cos(x)

plt.plot(x, y, color='green')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
